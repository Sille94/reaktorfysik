# %% [markdown]
# # OpenMC: Scripting
#
# Please indicate your name below, since you will need to submit this notebook completed latest the day after the datalab.
#
# Don't forget to save your progress during the datalab to avoid any loss due to crashes.

# %%
name='Gruppe 2'
print(name)
# Out:
# Gruppe 2

# %% [markdown]
# **Note** you will need to run Jupyter from an environment where openMC is available in order to run this notebook!
#
# During the first openMC datalab, we have covered the basics, and covered how to write a basic input, how to run it and how to post-process the results. Today we go one step further and will explore the real power of the python API. Namely that we can automatize calculations simply by defining a function which creates the input for us. Then we can write loops and automatically update our model. For this we will use the `Model()` class of openMC. This basically means that instead of exporting all the details of the run into xml, openMC will take care of this, when we call the `.run()` method of the class.
#
# We will learn about
#
# - the built in criticality search functionality of openMC (which is a wrapper for the scipy.optimization methods).
# - write our own script to determine the void-coefficient change of the LWR pincell at various fuel to moderator ratio
# - will write a tally to investigate the fuel utilization factor and the resonance escape probability.
#
# Let's get started with doing the necessary imports!

# %%
import openmc
import openmc.model
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Experiment 1
#
# First we will calculate the boron concentration at which the k-infinity of the pincell is 1.2. For a finite core, of course usually we would like to know the critical boron content, but now we have reflective boundaries (ie. no leakage), so for the demonstration we aim for higher than 1.0 multiplication factor.
#
# First, we will define the `pincell()` function. The expressions inside this function are probably similar from the previous datalab. We only did some small changes:
# - we have decreased the number of particles per batch: although we will have a worse accuracy, but we will need to run this input several times, and it is not sustainable to spend the datalab with waiting for the calculations to finish
# - we have not included a numeric ID for the `Material()` instances. In this case openMC will increment the ID number. Since in these examples we do not use the IDs for anything, we can live without controlling it. (If we kept the ID, openMC would send a warning all the time that the ID was already in use. It is a warning, so not an error, but still annoying).
# - we have added a small amount of boron to the water (in reality boric acid is added to the water)
# - we have removed the calls to the `export_to_xml()` methods.
# - since we removed the tallies, we included `settings.output = {'tallies': False}` (this is to make sure that in case a 'tallies.xml' file is present from an other run it is not used)
# - finally, at the end we create an instance `model = openmc.model.Model(geom, mats, settings)` and return it.

# %%
def pincell(bppm):
    #uo2 = openmc.Material(name="uo2",temperature=294)
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    #zirconium = openmc.Material(name="zirconium",temperature=294)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    water.set_density('g/cm3', 0.74)
    #THIS IS THE IMPORTANT NEW LINE COMPARED TO BEFORE!
    water.add_element('B', bppm*1e-6) 
    ###################################################
    water.add_s_alpha_beta('c_H_in_H2O')

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region

    pitch = 1.26
    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.
    ((0, 0, 0))
    src = openmc.Source(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %%
# openmc.config['cross_sections'] = '/root/jeff-3.3-hdf5/cross_sections.xml'
print(openmc.config['cross_sections'])
# Out:
# /root/jeff-3.3-hdf5/cross_sections.xml

# %% [markdown]
# Now we can perform a search for the boron concentration at which the multiplication factor is 1.2. This is a fairly similar root finding problem that we have done in datalab 5. In fact, if you look into the [source code](https://docs.openmc.org/en/stable/_modules/openmc/search.html#search_for_keff) of `openmc.search_for_keff` you will see that the function wraps the methods of scipy.optimize.
#
# We will need to pass as an input the function `pincell`, we can specify the lower and upper bound of the boron content to limit the interval of the search, and set the tolerance (ie. how accurate we want to be with the desired multiplication factor). The search will need some time, so while you wait you can start reading the next experiment!

# %%
os.system('rm *h5')
crit_ppm, guesses, keffs = openmc.search_for_keff(pincell, target=1.2, bracket=[2000., 3500.],
                                                  tol=1e-2, print_iterations=True)

print('Critical Boron Concentration: {:4.0f} ppm'.format(crit_ppm))
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:17
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#        60/1    1.37102    1.26022 +/- 0.00985
#        61/1    1.25482    1.26011 +/- 0.00966
#        62/1    1.29220    1.26073 +/- 0.00949
#        63/1    1.22708    1.26010 +/- 0.00933
#        64/1    1.25032    1.25992 +/- 0.00916
#        65/1    1.28650    1.26040 +/- 0.00900
#        66/1    1.19882    1.25930 +/- 0.00891
#        67/1    1.31753    1.26032 +/- 0.00881
#        68/1    1.33305    1.26158 +/- 0.00875
#        69/1    1.22304    1.26092 +/- 0.00862
#        70/1    1.26645    1.26101 +/- 0.00848
#        71/1    1.33322    1.26220 +/- 0.00842
#        72/1    1.30742    1.26293 +/- 0.00832
#        73/1    1.28590    1.26329 +/- 0.00819
#        74/1    1.25296    1.26313 +/- 0.00807
#        75/1    1.27582    1.26333 +/- 0.00794
#        76/1    1.27514    1.26350 +/- 0.00782
#        77/1    1.15538    1.26189 +/- 0.00787
#        78/1    1.22611    1.26136 +/- 0.00777
#        79/1    1.27556    1.26157 +/- 0.00766
#        80/1    1.35831    1.26295 +/- 0.00768
#        81/1    1.35129    1.26420 +/- 0.00767
#        82/1    1.37181    1.26569 +/- 0.00771
#        83/1    1.29732    1.26612 +/- 0.00762
#        84/1    1.22748    1.26560 +/- 0.00753
#        85/1    1.06408    1.26292 +/- 0.00790
#        86/1    1.14143    1.26132 +/- 0.00796
#        87/1    1.31035    1.26195 +/- 0.00788
#        88/1    1.30470    1.26250 +/- 0.00780
#        89/1    1.21595    1.26191 +/- 0.00772
#        90/1    1.39593    1.26359 +/- 0.00781
#        91/1    1.18087    1.26257 +/- 0.00778
#        92/1    1.30485    1.26308 +/- 0.00770
#        93/1    1.26666    1.26313 +/- 0.00760
#        94/1    1.12965    1.26154 +/- 0.00768
#        95/1    1.30200    1.26201 +/- 0.00760
#        96/1    1.27271    1.26214 +/- 0.00752
#        97/1    1.29507    1.26251 +/- 0.00744
#        98/1    1.20901    1.26191 +/- 0.00738
#        99/1    1.32393    1.26260 +/- 0.00733
#       100/1    1.17932    1.26168 +/- 0.00731
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.7839e-01 seconds
#    Reading cross sections          = 5.6335e-01 seconds
#  Total time in simulation          = 6.6333e-01 seconds
#    Time in transport only          = 6.4700e-01 seconds
#    Time in inactive batches        = 1.5942e-01 seconds
#    Time in active batches          = 5.0391e-01 seconds
#    Time synchronizing fission bank = 2.1049e-03 seconds
#      Sampling source sites         = 1.3729e-03 seconds
#      SEND/RECV source sites        = 3.3936e-04 seconds
#    Time accumulating tallies       = 9.3080e-05 seconds
#    Time writing statepoints        = 3.4052e-03 seconds
#  Total time for finalization       = 4.0000e-07 seconds
#  Total time elapsed                = 1.2538e+00 seconds
#  Calculation Rate (inactive)       = 31362.8 particles/second
#  Calculation Rate (active)         = 89302.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.25960 +/- 0.00660
#  k-effective (Track-length)  = 1.26168 +/- 0.00731
#  k-effective (Absorption)    = 1.24917 +/- 0.00459
#  Combined k-effective        = 1.25139 +/- 0.00455
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 1; Guess of 2.00e+03 produced a keff of 1.25139 +/- 0.00455
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:18
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.09610
#         2/1    1.24079
#         3/1    1.20116
#         4/1    1.16462
#         5/1    1.15155
#         6/1    1.17688
#         7/1    1.14630
#         8/1    1.04683
#         9/1    1.25992
#        10/1    1.08058
#        11/1    1.06653
#        12/1    1.20812    1.13733 +/- 0.07079
#        13/1    1.25618    1.17695 +/- 0.05692
#        14/1    1.28096    1.20295 +/- 0.04792
#        15/1    1.30448    1.22326 +/- 0.04231
#        16/1    1.09541    1.20195 +/- 0.04059
#        17/1    1.13984    1.19308 +/- 0.03543
#        18/1    1.21907    1.19633 +/- 0.03086
#        19/1    1.21362    1.19825 +/- 0.02728
#        20/1    1.16473    1.19490 +/- 0.02463
#        21/1    1.10908    1.18709 +/- 0.02361
#        22/1    1.20901    1.18892 +/- 0.02163
#        23/1    0.98268    1.17305 +/- 0.02544
#        24/1    1.38176    1.18796 +/- 0.02788
#        25/1    1.31509    1.19644 +/- 0.02730
#        26/1    1.15423    1.19380 +/- 0.02567
#        27/1    1.23784    1.19639 +/- 0.02426
#        28/1    1.18256    1.19562 +/- 0.02288
#        29/1    1.09972    1.19057 +/- 0.02222
#        30/1    1.21619    1.19186 +/- 0.02112
#        31/1    1.23017    1.19368 +/- 0.02017
#        32/1    1.17286    1.19273 +/- 0.01926
#        33/1    1.15253    1.19099 +/- 0.01849
#        34/1    1.07546    1.18617 +/- 0.01834
#        35/1    1.18406    1.18609 +/- 0.01759
#        36/1    1.32091    1.19127 +/- 0.01768
#        37/1    1.14951    1.18973 +/- 0.01708
#        38/1    1.26509    1.19242 +/- 0.01668
#        39/1    1.21394    1.19316 +/- 0.01611
#        40/1    1.21828    1.19400 +/- 0.01559
#        41/1    1.06510    1.18984 +/- 0.01564
#        42/1    1.21821    1.19073 +/- 0.01517
#        43/1    1.20549    1.19117 +/- 0.01471
#        44/1    1.25594    1.19308 +/- 0.01440
#        45/1    1.21611    1.19374 +/- 0.01399
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2812e-01 seconds
#    Reading cross sections          = 4.0711e-01 seconds
#  Total time in simulation          = 8.2863e-01 seconds
#    Time in transport only          = 8.1221e-01 seconds
#    Time in inactive batches        = 1.8876e-01 seconds
#    Time in active batches          = 6.3987e-01 seconds
#    Time synchronizing fission bank = 2.5189e-03 seconds
#      Sampling source sites         = 1.5995e-03 seconds
#      SEND/RECV source sites        = 4.1859e-04 seconds
#    Time accumulating tallies       = 3.5144e-05 seconds
#    Time writing statepoints        = 3.0884e-03 seconds
#  Total time for finalization       = 3.9000e-07 seconds
#  Total time elapsed                = 1.2832e+00 seconds
#  Calculation Rate (inactive)       = 26488.9 particles/second
#  Calculation Rate (active)         = 70326.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18424 +/- 0.00618
#  k-effective (Track-length)  = 1.19041 +/- 0.00777
#  k-effective (Absorption)    = 1.17680 +/- 0.00428
#  Combined k-effective        = 1.17838 +/- 0.00424
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 2; Guess of 3.50e+03 produced a keff of 1.17838 +/- 0.00424
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:20
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13667
#         2/1    1.17562
#         3/1    1.12152
#         4/1    1.23725
#         5/1    1.25547
#         6/1    1.15603
#         7/1    1.28054
#         8/1    1.24249
#         9/1    1.21129
#        10/1    1.20445
#        11/1    1.22727
#        12/1    1.21691    1.22209 +/- 0.00518
#        13/1    1.12596    1.19005 +/- 0.03218
#        14/1    1.17642    1.18664 +/- 0.02301
#        15/1    1.15122    1.17956 +/- 0.01918
#        16/1    1.24503    1.19047 +/- 0.01909
#        17/1    1.15605    1.18555 +/- 0.01686
#        18/1    1.25218    1.19388 +/- 0.01681
#        19/1    1.10772    1.18431 +/- 0.01765
#        20/1    1.23386    1.18926 +/- 0.01655
#        21/1    1.19722    1.18998 +/- 0.01498
#        22/1    1.25626    1.19551 +/- 0.01475
#        23/1    1.26191    1.20062 +/- 0.01450
#        24/1    1.18731    1.19966 +/- 0.01346
#        25/1    1.14989    1.19635 +/- 0.01296
#        26/1    1.29316    1.20240 +/- 0.01355
#        27/1    1.21721    1.20327 +/- 0.01276
#        28/1    1.27187    1.20708 +/- 0.01262
#        29/1    1.17187    1.20523 +/- 0.01208
#        30/1    1.06519    1.19822 +/- 0.01343
#        31/1    1.20818    1.19870 +/- 0.01278
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.0638e-01 seconds
#    Reading cross sections          = 4.8895e-01 seconds
#  Total time in simulation          = 7.0008e-01 seconds
#    Time in transport only          = 6.8229e-01 seconds
#    Time in inactive batches        = 1.1945e-01 seconds
#    Time in active batches          = 5.8062e-01 seconds
#    Time synchronizing fission bank = 2.4031e-03 seconds
#      Sampling source sites         = 1.5229e-03 seconds
#      SEND/RECV source sites        = 4.3750e-04 seconds
#    Time accumulating tallies       = 3.4618e-05 seconds
#    Time writing statepoints        = 3.0993e-03 seconds
#  Total time for finalization       = 5.6100e-07 seconds
#  Total time elapsed                = 1.2250e+00 seconds
#  Calculation Rate (inactive)       = 41856.8 particles/second
#  Calculation Rate (active)         = 77503.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.21818 +/- 0.00570
#  k-effective (Track-length)  = 1.22008 +/- 0.00648
#  k-effective (Absorption)    = 1.21921 +/- 0.00458
#  Combined k-effective        = 1.21929 +/- 0.00380
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 3; Guess of 2.75e+03 produced a keff of 1.21929 +/- 0.00380
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:21
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.11280
#         2/1    1.24393
#         3/1    1.19513
#         4/1    1.18116
#         5/1    1.16380
#         6/1    1.23193
#         7/1    1.19529
#         8/1    1.06534
#         9/1    1.09513
#        10/1    1.13212
#        11/1    1.33068
#        12/1    1.24370    1.28719 +/- 0.04349
#        13/1    1.19612    1.25683 +/- 0.03939
#        14/1    1.16710    1.23440 +/- 0.03577
#        15/1    1.09387    1.20629 +/- 0.03946
#        16/1    1.15786    1.19822 +/- 0.03322
#        17/1    1.27753    1.20955 +/- 0.03027
#        80/1    1.24191    1.18396 +/- 0.00802
#        81/1    1.28560    1.18539 +/- 0.00803
#        82/1    1.26227    1.18646 +/- 0.00799
#        83/1    1.14874    1.18594 +/- 0.00790
#        84/1    1.29185    1.18737 +/- 0.00792
#        85/1    1.28629    1.18869 +/- 0.00793
#        86/1    1.15971    1.18831 +/- 0.00783
#        87/1    1.04814    1.18649 +/- 0.00794
#        88/1    1.25826    1.18741 +/- 0.00789
#        89/1    1.18163    1.18734 +/- 0.00779
#        90/1    1.10268    1.18628 +/- 0.00776
#        91/1    1.27621    1.18739 +/- 0.00775
#        92/1    1.16631    1.18713 +/- 0.00766
#        93/1    1.21355    1.18745 +/- 0.00757
#        94/1    1.22966    1.18795 +/- 0.00750
#        95/1    1.11210    1.18706 +/- 0.00746
#        96/1    1.16491    1.18680 +/- 0.00738
#        97/1    1.23857    1.18740 +/- 0.00732
#        98/1    1.28494    1.18851 +/- 0.00732
#        99/1    1.23554    1.18904 +/- 0.00726
#       100/1    1.21454    1.18932 +/- 0.00718
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2257e-01 seconds
#    Reading cross sections          = 4.0784e-01 seconds
#  Total time in simulation          = 6.8312e-01 seconds
#    Time in transport only          = 6.5427e-01 seconds
#    Time in inactive batches        = 1.2236e-01 seconds
#    Time in active batches          = 5.6076e-01 seconds
#    Time synchronizing fission bank = 7.9845e-03 seconds
#      Sampling source sites         = 2.1647e-03 seconds
#      SEND/RECV source sites        = 2.2219e-03 seconds
#    Time accumulating tallies       = 4.0334e-05 seconds
#    Time writing statepoints        = 5.4296e-03 seconds
#  Total time for finalization       = 6.3100e-07 seconds
#  Total time elapsed                = 1.1201e+00 seconds
#  Calculation Rate (inactive)       = 40863 particles/second
#  Calculation Rate (active)         = 80248.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18965 +/- 0.00557
#  k-effective (Track-length)  = 1.18932 +/- 0.00718
#  k-effective (Absorption)    = 1.19267 +/- 0.00417
#  Combined k-effective        = 1.19178 +/- 0.00383
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 4; Guess of 3.12e+03 produced a keff of 1.19178 +/- 0.00383
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:22
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature:
#        67/1    1.11246    1.20096 +/- 0.00785
#        68/1    1.18764    1.20073 +/- 0.00771
#        69/1    1.18325    1.20044 +/- 0.00759
#        70/1    1.25938    1.20142 +/- 0.00752
#        71/1    1.20661    1.20150 +/- 0.00740
#        72/1    1.14224    1.20055 +/- 0.00734
#        73/1    1.16500    1.19998 +/- 0.00725
#        74/1    1.27003    1.20108 +/- 0.00722
#        75/1    1.21621    1.20131 +/- 0.00711
#        76/1    1.23426    1.20181 +/- 0.00702
#        77/1    1.21863    1.20206 +/- 0.00692
#        78/1    1.24426    1.20268 +/- 0.00684
#        79/1    1.17101    1.20222 +/- 0.00676
#        80/1    1.12320    1.20109 +/- 0.00676
#        81/1    1.18585    1.20088 +/- 0.00666
#        82/1    1.16163    1.20033 +/- 0.00659
#        83/1    1.22153    1.20062 +/- 0.00651
#        84/1    1.23002    1.20102 +/- 0.00643
#        85/1    1.22607    1.20136 +/- 0.00635
#        86/1    1.16669    1.20090 +/- 0.00629
#        87/1    1.13933    1.20010 +/- 0.00626
#        88/1    1.26296    1.20091 +/- 0.00623
#        89/1    1.10057    1.19964 +/- 0.00628
#        90/1    1.13028    1.19877 +/- 0.00626
#        91/1    1.22225    1.19906 +/- 0.00619
#        92/1    1.24718    1.19965 +/- 0.00614
#        93/1    1.25197    1.20028 +/- 0.00610
#        94/1    1.20932    1.20038 +/- 0.00603
#        95/1    1.16429    1.19996 +/- 0.00597
#        96/1    1.25698    1.20062 +/- 0.00594
#        97/1    1.22216    1.20087 +/- 0.00587
#        98/1    1.32372    1.20227 +/- 0.00597
#        99/1    1.19369    1.20217 +/- 0.00591
#       100/1    1.15531    1.20165 +/- 0.00586
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.8649e-01 seconds
#    Reading cross sections          = 4.6942e-01 seconds
#  Total time in simulation          = 6.4661e-01 seconds
#    Time in transport only          = 6.3074e-01 seconds
#    Time in inactive batches        = 1.5310e-01 seconds
#    Time in active batches          = 4.9351e-01 seconds
#    Time synchronizing fission bank = 2.2445e-03 seconds
#      Sampling source sites         = 1.3903e-03 seconds
#      SEND/RECV source sites        = 4.0643e-04 seconds
#    Time accumulating tallies       = 3.1156e-05 seconds
#    Time writing statepoints        = 5.0435e-03 seconds
#  Total time for finalization       = 4.2100e-07 seconds
#  Total time elapsed                = 1.1518e+00 seconds
#  Calculation Rate (inactive)       = 32658.4 particles/second
#  Calculation Rate (active)         = 91184.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.20373 +/- 0.00530
#  k-effective (Track-length)  = 1.20165 +/- 0.00586
#  k-effective (Absorption)    = 1.19908 +/- 0.00467
#  Combined k-effective        = 1.20039 +/- 0.00404
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 5; Guess of 2.94e+03 produced a keff of 1.20039 +/- 0.00404
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:24
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.12287
#         2/1    1.22438
#         3/1    1.13554
#         4/1    1.10095
#         5/1    1.38708
#         6/1    1.23125
#         7/1    1.27495
#         8/1    1.16902
#         9/1    1.13563
#        10/1    1.13196
#        11/1    1.22723
#        12/1    1.23778    1.23250 +/- 0.00527
#        13/1    1.24777    1.23759 +/- 0.00593
#        14/1    1.10735    1.20503 +/- 0.03283
#        15/1    1.24132    1.21229 +/- 0.02644
#        16/1    1.24481    1.21771 +/- 0.02226
#        17/1    1.27429    1.22579 +/- 0.02048
#        18/1    1.12888    1.21368 +/- 0.02148
#        19/1    1.11077    1.20224 +/- 0.02212
#        20/1    1.28523    1.21054 +/- 0.02146
#        21/1    1.16184    1.20612 +/- 0.01991
#        22/1    1.24317    1.20920 +/- 0.01843
#        23/1    1.16392    1.20572 +/- 0.01731
#        24/1    1.15543    1.20213 +/- 0.01642
#        25/1    1.25062    1.20536 +/- 0.01563
#        26/1    1.24840    1.20805 +/- 0.01486
#        27/1    1.22114    1.20882 +/- 0.01398
#        28/1    1.25541    1.21141 +/- 0.01344
#        29/1    1.16248    1.20883 +/- 0.01297
#        30/1    1.28462    1.21262 +/- 0.01287
#        31/1    1.15622    1.20994 +/- 0.01253
#        32/1    1.12002    1.20585 +/- 0.01263
#        33/1    1.11790    1.20203 +/- 0.01266
#        34/1    1.11354    1.19834 +/- 0.01267
#        35/1    1.12792    1.19552 +/- 0.01247
#        36/1    1.26754    1.19829 +/- 0.01230
#        37/1    1.27650    1.20119 +/- 0.01219
#        38/1    1.27152    1.20370 +/- 0.01201
#        39/1    1.14941    1.20183 +/- 0.01174
#        40/1    1.19777    1.20169 +/- 0.01134
#        41/1    1.17817    1.20093 +/- 0.01099
#        42/1    1.22937    1.20182 +/- 0.01068
#        43/1    1.12163    1.19939 +/- 0.01063
#        44/1    1.40583    1.20547 +/- 0.01197
#        45/1    1.27941    1.20758 +/- 0.01181
# ...
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0
particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18794 +/- 0.00617
#  k-effective (Track-length)  = 1.18919 +/- 0.00727
#  k-effective (Absorption)    = 1.19430 +/- 0.00504
#  Combined k-effective        = 1.19242 +/- 0.00463
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 7; Guess of 3.08e+03 produced a keff of 1.19242 +/- 0.00463
# /openmc_venv/lib/python3.12/site-packages/openmc/source.py:668: FutureWarning: This class is deprecated in favor of 'IndependentSource'
#   warnings.warn(
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:12:26
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading B10 from /root/jeff-3.3-hdf5/B10.h5
#  Reading B11 from /root/jeff-3.3-hdf5/B11.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.11033
#         2/1    1.22093
#         3/1    1.29804
#         4/1    1.23374
#         5/1    1.22942
#         6/1    1.29710
#         7/1    1.32847
#         8/1    1.19549
#         9/1    1.31776
#        10/1    1.13997
#        11/1    1.20484
#        12/1    1.21996    1.21240 +/- 0.00756
#        13/1    1.19088    1.20523 +/- 0.00840
#        14/1    1.29431    1.22750 +/- 0.02305
#        15/1    1.25369    1.23274 +/- 0.01861
#        16/1    1.23295    1.23277 +/- 0.01519
#        17/1    1.12943    1.21801 +/- 0.01957
#        18/1    1.32906    1.23189 +/- 0.02190
#        19/1    1.18176    1.22632 +/- 0.02010
#        20/1    1.18423    1.22211 +/- 0.01847
#        21/1    1.19777    1.21990 +/- 0.01685
#        22/1    1.13865    1.21313 +/- 0.01681
#        23/1    1.19779    1.21195 +/- 0.01551
#        24/1    1.19770    1.21093 +/- 0.01439
#        25/1    1.15111    1.20694 +/- 0.01398
#        26/1    1.19462    1.20617 +/- 0.01310
#        27/1    1.24850    1.20866 +/- 0.01255
#        28/1    1.12191    1.20384 +/- 0.01278
#        29/1    1.10691    1.19874 +/- 0.01312
#        30/1    1.24617    1.20111 +/- 0.01267
#        31/1    1.10753    1.19666 +/- 0.01285
#        32/1    1.15112    1.19459 +/- 0.01243
#        33/1    1.17165    1.19359 +/- 0.01191
#        34/1    1.14034    1.19137 +/- 0.01162
#        35/1    1.26688    1.19439 +/- 0.01155
#        36/1    1.15848    1.19301 +/- 0.01118
#        37/1    1.19588    1.19312 +/- 0.01076
#        38/1    1.26675    1.19575 +/- 0.01070
#        39/1    1.17998    1.19520 +/- 0.01034
#        40/1    1.26812    1.19763 +/- 0.01028
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.1136e-01 seconds
#    Reading cross sections          = 3.9635e-01 seconds
#  Total time in simulation          = 4.9261e-01 seconds
#    Time in transport only          = 4.7717e-01 seconds
#    Time in inactive batches        = 1.1667e-01 seconds
#    Time in active batches          = 3.7594e-01 seconds
#    Time synchronizing fission bank = 2.5937e-03 seconds
#      Sampling source sites         = 1.4963e-03 seconds
#      SEND/RECV source sites        = 4.1754e-04 seconds
#    Time accumulating tallies       = 2.9082e-05 seconds
#    Time writing statepoints        = 4.5842e-03 seconds
#  Total time for finalization       = 4.2100e-07 seconds
#  Total time elapsed                = 9.1708e-01 seconds
#  Calculation Rate (inactive)       = 42854.4 particles/second
#  Calculation Rate (active)         = 119701 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.20214 +/- 0.00555
#  k-effective (Track-length)  = 1.20376 +/- 0.00659
#  k-effective (Absorption)    = 1.20271 +/- 0.00489
#  Combined k-effective        = 1.20264 +/- 0.00444
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
# Iteration: 8; Guess of 3.05e+03 produced a keff of 1.20264 +/- 0.00444
# Critical Boron Concentration: 3055 ppm

# %% [markdown]
# We can visualize the guesses by the optimization algorithm, and see how the boron content converged to the correct amount.

# %%
plt.figure()
for g,k in zip(guesses,keffs):
    plt.scatter(g,k.nominal_value,color='k')
plt.xlabel('boron content (ppm)')
plt.ylabel('k-inf')
plt.scatter(crit_ppm,1.2,color='r')
plt.show()

# %% [markdown]
# ## Experiment 2
#
# During the lectures we have learnt about the reactivity feedback coefficients. Today we are going to investigate the void coefficient for various moderator to fuel ratios. The moderator to fuel ratio can be defined in the rectangular pincell as
#
# $$mfr=\frac{p^2-r_{clad}^2\pi}{r_{fuel}^2\pi}$$
#
# can be simply modified by changing the pitch $p$.
#
# The void constant of the fuel can be modified by changing the density of the coolant. We can use the following simple relationship:
#
# $$\rho_{coolant}=\rho_0(1-void[\%]/100)$$
#
# where $\rho_0=0.74$ g/cm3. In practice, of course we will never obtain a zero density even for a fully voided core. Also, it is worth mentioning that void levels investigated here are never reached in normal operations for a PWR, but are however the nominal levels for a BWR. Nevertheless, the goal of the exercise is not to investigate exact reactor operation scenarios, rather to provide a physicist insight for understanding how significantly lowering the density of the moderator affects the multiplication factor.
#
# First create a `pincell()` function where the user can modify the pitch and the void content. The function should return a `Model()` object. (You do not need to include boron in the coolant for this exercise).

# %%
# def pincell(pitch,void):
#     #Complete the function
#     return model

def pincell_exp2(pitch,void):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    roh_0 = 0.74
    water.set_density('g/cm3', roh_0 * (1 - void / 100))
    water.add_s_alpha_beta('c_H_in_H2O') #thermal scattering law to better model how low-energy neutrons interact with hydrogen bound in water molecules.

    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region


    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.IndependentSource(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    model = openmc.model.Model(geom, mats, settings)
    return model

# %% [markdown]
# If a model is created with the pincell, it can be run with openMC with
#
# ```python
#     mod = pincell(1.26,0.0)
#     output = mod.run()
# ```
#
# where the `output` variable will contain the path to the state point file.
#
# Now we will call this function in a loop for several pitch values and then as a nested loop for three void values at each moderator to fuel ratio. Since the code will create the statepoint files with the same name, make sure that you store the quantity of interest (for example in arrays) before overwriting the output. At each moderator to fuel ratio you can perform a fit to estimate the void-coefficient (it can be a linear fit, considering that we will have only three values to fit for).
#
# Note that in case the computation seems to be slow, you should not use more than 500 particles per batch (you should get reasonably good results with 500 particles as well).
#
# Reminder: the statepoint files can be read with `sp = openmc.StatePoint(pathtofile)`, and the multiplication factor accessed with `sp.keff.nominal_value`.

# %%
# from scipy.optimize import curve_fit

# os.system('rm *h5')

# pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05]#,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]
# void=[0,25,50]

# #initialize lists to store results
# for pi in pitch:
#     #initialize list to store keff values
#     for v in void:
#         #your code to call the pincell, run it, and store the k-effective comes here
#         os.system('rm %s'%output)
#         os.system('rm summary.h5')
#     #your code to estimate the void-coefficient from a linear fit. and to store the data


import os
import tempfile

pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05]  # ,2.15,2.25,...
void=[0,25,50]

# Initialize dictionaries to store results
k_effs={}       # store k_eff values per pitch
void_coeffs={}  # store void coefficients per pitch

# Close any previously opened global StatePoint handle if it exists.
try:
    sp.close()
except Exception:
    pass

for pi in pitch:
    k_vals=[]
    for v in void:
        mod = pincell_exp2(pi, v)
        # Run each case in an isolated folder to avoid statepoint/summary file collisions.
        with tempfile.TemporaryDirectory(prefix='openmc_exp2_') as run_dir:
            output = mod.run(cwd=run_dir)
            with openmc.StatePoint(output) as sp_local:
                k_val = sp_local.keff.nominal_value
        k_vals.append(k_val)

    # Estimate void coefficient as d(Δk/k)/d(void%) using 0% void as reference
    k_effs[pi] = k_vals
    k0 = k_vals[0]
    rel_dk_over_k = [(k - k0) / k0 for k in k_vals]
    slope, _ = np.polyfit(void, rel_dk_over_k, 1)
    void_coeffs[pi] = slope
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:38
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13108
#         2/1    1.19509
#         3/1    1.06296
#         4/1    1.08344
#         5/1    1.12917
#         6/1    1.11927
#         7/1    1.24359
#         8/1    1.10066
#         9/1    1.28129
#        10/1    0.98728
#        11/1    1.18755
#        12/1    1.13699    1.16227 +/- 0.02528
#        13/1    1.11054    1.14503 +/- 0.02259
#        14/1    1.03393    1.11725 +/- 0.03204
#        15/1    1.32699    1.15920 +/- 0.04874
#        16/1    1.14684    1.15714 +/- 0.03985
#        17/1    1.04378    1.14095 +/- 0.03737
#        18/1    1.07724    1.13298 +/- 0.03333
#        19/1    1.14427    1.13424 +/- 0.02942
#        20/1    1.16119    1.13693 +/- 0.02645
#        21/1    1.13675    1.13692 +/- 0.02393
#        22/1    1.02633    1.12770 +/- 0.02371
#        23/1    0.94762    1.11385 +/- 0.02583
#        24/1    1.10315    1.11308 +/- 0.02393
#        25/1    1.13876    1.11480 +/- 0.02234
#        26/1    1.02921    1.10945 +/- 0.02157
#        27/1    1.13992    1.11124 +/- 0.02034
#        28/1    1.15243    1.11353 +/- 0.01932
#        29/1    1.09742    1.11268 +/- 0.01829
#        30/1    1.15102    1.11460 +/- 0.01746
#        31/1    1.07832    1.11287 +/- 0.01670
#        32/1    1.15255    1.11467 +/- 0.01602
#        33/1    1.00883    1.11007 +/- 0.01598
#        34/1    0.95902    1.10378 +/- 0.01655
#        35/1    1.04689    1.10150 +/- 0.01603
#        36/1    1.06284    1.10001 +/- 0.01548
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.2552e-01 seconds
#    Reading cross sections          = 5.9016e-01 seconds
#  Total time in simulation          = 8.5965e-01 seconds
#    Time in transport only          = 8.4122e-01 seconds
#    Time in inactive batches        = 1.8258e-01 seconds
#    Time in active batches          = 6.7708e-01 seconds
#    Time synchronizing fission bank = 2.7734e-03 seconds
#      Sampling source sites         = 1.5597e-03 seconds
#      SEND/RECV source sites        = 4.6531e-04 seconds
#    Time accumulating tallies       = 3.2451e-05 seconds
#    Time writing statepoints        = 4.0312e-03 seconds
#  Total time for finalization       = 5.0100e-07 seconds
#  Total time elapsed                = 1.4966e+00 seconds
#  Calculation Rate (inactive)       = 27385.8 particles/second
#  Calculation Rate (active)         = 66462.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.09352 +/- 0.00613
#  k-effective (Track-length)  = 1.09372 +/- 0.00779
#  k-effective (Absorption)    = 1.08592 +/- 0.00502
#  Combined k-effective        = 1.08872 +/- 0.00448
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:39
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.15570
#         2/1    0.96085
#         3/1    0.96607
#         4/1    0.96677
#         5/1    1.07685
#         6/1    1.06634
#         7/1    1.14019
#         8/1    0.96024
#         9/1    1.10687
#        10/1    1.01079
#        11/1    1.01477
#        12/1    1.02808    1.02142 +/- 0.00665
#        13/1    0.98252    1.00846 +/- 0.01352
#        14/1    0.98949    1.00372 +/- 0.01067
#        15/1    1.07228    1.01743 +/- 0.01601
#        16/1    0.99853    1.01428 +/- 0.01345
#        17/1    0.87938    0.99501 +/- 0.02237
#        18/1    1.04163    1.00083 +/- 0.02023
#        19/1    0.89325    0.98888 +/- 0.02148
#        20/1    0.96040    0.98603 +/- 0.01942
#        21/1    0.99495    0.98684 +/- 0.01758
#        22/1    1.07839    0.99447 +/- 0.01777
#        23/1    1.04651    0.99847 +/- 0.01683
#        24/1    1.01682    0.99979 +/- 0.01564
#        25/1    1.04883    1.00306 +/- 0.01492
#        26/1    1.01321    1.00369 +/- 0.01397
#        27/1    0.94586    1.00029 +/- 0.01356
#        28/1    1.05116    1.00311 +/- 0.01309
#        29/1    1.06081    1.00615 +/- 0.01275
#        92/1    0.98222    1.02284 +/- 0.00579
#        93/1    0.88419    1.02117 +/- 0.00596
#        94/1    1.07806    1.02185 +/- 0.00593
#        95/1    1.00208    1.02162 +/- 0.00586
#        96/1    1.05467    1.02200 +/- 0.00581
#        97/1    1.05607    1.02239 +/- 0.00575
#        98/1    1.00544    1.02220 +/- 0.00569
#        99/1    1.02173    1.02220 +/- 0.00563
#       100/1    1.00762    1.02203 +/- 0.00557
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.8910e-01 seconds
#    Reading cross sections          = 4.6487e-01 seconds
#  Total time in simulation          = 8.0980e-01 seconds
#    Time in transport only          = 7.9513e-01 seconds
#    Time in inactive batches        = 1.3625e-01 seconds
#    Time in active batches          = 6.7355e-01 seconds
#    Time synchronizing fission bank = 2.5745e-03 seconds
#      Sampling source sites         = 1.3708e-03 seconds
#      SEND/RECV source sites        = 4.5966e-04 seconds
#    Time accumulating tallies       = 3.5048e-05 seconds
#    Time writing statepoints        = 2.1696e-03 seconds
#  Total time for finalization       = 3.8100e-07 seconds
#  Total time elapsed                = 1.3132e+00 seconds
#  Calculation Rate (inactive)       = 36696.4 particles/second
#  Calculation Rate (active)         = 66810.6 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.02386 +/- 0.00506
#  k-effective (Track-length)  = 1.02203 +/- 0.00557
#  k-effective (Absorption)    = 1.02006 +/- 0.00440
#  Combined k-effective        = 1.02151 +/- 0.00372
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:41
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    0.92028
#         2/1    1.00527
#         3/1    0.92007
#         4/1    0.88346
#         5/1    1.02149
#         6/1    0.88414
#         7/1    0.90863
#         8/1    0.89445
#         9/1    0.92255
#        10/1    1.00303
#        11/1    0.89330
#        12/1    0.96079    0.92704 +/- 0.03375
#        13/1    0.98381    0.94596 +/- 0.02716
#        14/1    1.04361    0.97038 +/- 0.03106
#        15/1    0.89334    0.95497 +/- 0.02857
#        16/1    0.99155    0.96106 +/- 0.02411
#        17/1    0.83363    0.94286 +/- 0.02733
#        18/1    0.95092    0.94387 +/- 0.02369
#        19/1    0.88466    0.93729 +/- 0.02190
#        20/1    0.87144    0.93070 +/- 0.02067
#        21/1    0.95329    0.93276 +/- 0.01881
#        22/1    0.93687    0.93310 +/- 0.01717
#        85/1    0.89817    0.92922 +/- 0.00659
#        86/1    0.92052    0.92910 +/- 0.00650
#        87/1    0.89586    0.92867 +/- 0.00643
#        88/1    0.86902    0.92791 +/- 0.00639
#        89/1    0.97860    0.92855 +/- 0.00634
#        90/1    0.91797    0.92841 +/- 0.00627
#        91/1    0.93466    0.92849 +/- 0.00619
#        92/1    0.82528    0.92723 +/- 0.00624
#        93/1    0.86554    0.92649 +/- 0.00621
#        94/1    0.90942    0.92629 +/- 0.00614
#        95/1    0.94713    0.92653 +/- 0.00607
#        96/1    0.99800    0.92736 +/- 0.00606
#        97/1    0.84652    0.92643 +/- 0.00606
#        98/1    0.96684    0.92689 +/- 0.00601
#        99/1    0.90938    0.92670 +/- 0.00594
#       100/1    0.97483    0.92723 +/- 0.00590
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.7839e-01 seconds
#    Reading cross sections          = 3.4820e-01 seconds
#  Total time in simulation          = 8.7824e-01 seconds
#    Time in transport only          = 8.6441e-01 seconds
#    Time in inactive batches        = 2.1403e-01 seconds
#    Time in active batches          = 6.6422e-01 seconds
#    Time synchronizing fission bank = 2.1615e-03 seconds
#      Sampling source sites         = 1.4064e-03 seconds
#      SEND/RECV source sites        = 3.4940e-04 seconds
#    Time accumulating tallies       = 3.4518e-05 seconds
#    Time writing statepoints        = 2.7444e-03 seconds
#  Total time for finalization       = 6.3100e-07 seconds
#  Total time elapsed                = 1.2684e+00 seconds
#  Calculation Rate (inactive)       = 23361.5 particles/second
#  Calculation Rate (active)         = 67749 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 0.93042 +/- 0.00511
#  k-effective (Track-length)  = 0.92723 +/- 0.00590
#  k-effective (Absorption)    = 0.93189 +/- 0.00510
#  Combined k-effective        = 0.93216 +/- 0.00413
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:42
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.19083
#         2/1    1.15291
#         3/1    1.32912
#         4/1    1.31115
#         5/1    1.14856
#         6/1    1.16483
#         7/1    1.16505
#         8/1    1.30030
#         9/1    1.23075
#        10/1    1.22838
#        11/1    1.28657
#        12/1    1.14742    1.21699 +/- 0.06958
#        13/1    1.24648    1.22682 +/- 0.04136
#        14/1    1.14893    1.20735 +/- 0.03513
#        15/1    1.20045    1.20597 +/- 0.02725
#        78/1    1.09665    1.21712 +/- 0.00889
#        79/1    1.21285    1.21706 +/- 0.00876
#        80/1    1.27228    1.21785 +/- 0.00867
#        81/1    1.31058    1.21916 +/- 0.00864
#        82/1    1.22818    1.21928 +/- 0.00852
#        83/1    1.15326    1.21838 +/- 0.00846
#        84/1    1.15577    1.21753 +/- 0.00838
#        85/1    1.18541    1.21710 +/- 0.00828
#        86/1    1.27644    1.21788 +/- 0.00821
#        87/1    1.15459    1.21706 +/- 0.00814
#        88/1    1.28114    1.21788 +/- 0.00808
#        89/1    1.29928    1.21891 +/- 0.00804
#        90/1    1.12885    1.21779 +/- 0.00802
#        91/1    1.17168    1.21722 +/- 0.00794
#        92/1    1.24863    1.21760 +/- 0.00785
#        93/1    1.40247    1.21983 +/- 0.00807
#        94/1    1.21439    1.21976 +/- 0.00798
#        95/1    1.17907    1.21929 +/- 0.00790
#        96/1    1.20310    1.21910 +/- 0.00781
#        97/1    1.27199    1.21971 +/- 0.00774
#        98/1    1.16287    1.21906 +/- 0.00768
#        99/1    1.14815    1.21826 +/- 0.00763
#       100/1    1.35238    1.21975 +/- 0.00769
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.5759e-01 seconds
#    Reading cross sections          = 3.4185e-01 seconds
#  Total time in simulation          = 8.1824e-01 seconds
#    Time in transport only          = 8.0178e-01 seconds
#    Time in inactive batches        = 1.8267e-01 seconds
#    Time in active batches          = 6.3558e-01 seconds
#    Time synchronizing fission bank = 2.4818e-03 seconds
#      Sampling source sites         = 1.6833e-03 seconds
#      SEND/RECV source sites        = 3.9954e-04 seconds
#    Time accumulating tallies       = 3.6604e-05 seconds
#    Time writing statepoints        = 2.3874e-03 seconds
#  Total time for finalization       = 5.3100e-07 seconds
#  Total time elapsed                = 1.1876e+00 seconds
#  Calculation Rate (inactive)       = 27372.3 particles/second
#  Calculation Rate (active)         = 70801.9 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.22226 +/- 0.00579
#  k-effective (Track-length)  = 1.21975 +/- 0.00769
#  k-effective (Absorption)    = 1.22786 +/- 0.00473
#  Combined k-effective        = 1.22643 +/- 0.00447
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:43
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        71/1    1.13483    1.16253 +/- 0.01019
#        72/1    1.13763    1.16213 +/- 0.01003
#        73/1    1.26924    1.16383 +/- 0.01002
#        74/1    1.14420    1.16352 +/- 0.00987
#        75/1    1.16622    1.16356 +/- 0.00971
#        76/1    1.19169    1.16399 +/- 0.00957
#        77/1    1.05380    1.16235 +/- 0.00957
#        78/1    1.09599    1.16137 +/- 0.00948
#        79/1    1.09722    1.16044 +/- 0.00939
#        80/1    1.24935    1.16171 +/- 0.00934
#        81/1    1.19934    1.16224 +/- 0.00922
#        82/1    1.18117    1.16250 +/- 0.00910
#        83/1    1.23943    1.16356 +/- 0.00903
#        84/1    1.09520    1.16263 +/- 0.00896
#        85/1    1.20411    1.16319 +/- 0.00886
#        86/1    1.16805    1.16325 +/- 0.00874
#        87/1    1.14705    1.16304 +/- 0.00863
#        88/1    1.25961    1.16428 +/- 0.00861
#        89/1    1.23038    1.16511 +/- 0.00854
#        90/1    1.22639    1.16588 +/- 0.00846
#        91/1    1.25203    1.16694 +/- 0.00843
#        92/1    1.19660    1.16731 +/- 0.00833
#        93/1    1.23939    1.16817 +/- 0.00828
#        94/1    1.11221    1.16751 +/- 0.00820
#        95/1    1.09644    1.16667 +/- 0.00815
#        96/1    1.14601    1.16643 +/- 0.00806
#        97/1    1.17452    1.16652 +/- 0.00797
#        98/1    0.95161    1.16408 +/- 0.00824
#        99/1    1.16814    1.16413 +/- 0.00815
#       100/1    1.14244    1.16389 +/- 0.00806
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.6116e-01 seconds
#    Reading cross sections          = 4.3111e-01 seconds
#  Total time in simulation          = 7.1524e-01 seconds
#    Time in transport only          = 6.9917e-01 seconds
#    Time in inactive batches        = 1.3467e-01 seconds
#    Time in active batches          = 5.8057e-01 seconds
#    Time synchronizing fission bank = 2.2009e-03 seconds
#      Sampling source sites         = 1.3178e-03 seconds
#      SEND/RECV source sites        = 3.5294e-04 seconds
#    Time accumulating tallies       = 3.7655e-05 seconds
#    Time writing statepoints        = 2.4342e-03 seconds
#  Total time for finalization       = 6.1200e-07 seconds
#  Total time elapsed                = 1.1960e+00 seconds
#  Calculation Rate (inactive)       = 37129 particles/second
#  Calculation Rate (active)         = 77509.5 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.16280 +/- 0.00681
#  k-effective (Track-length)  = 1.16389 +/- 0.00806
#  k-effective (Absorption)    = 1.15607 +/- 0.00553
#  Combined k-effective        = 1.15821 +/- 0.00518
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:14:45
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature:
#        91/1    1.40439    1.44636 +/- 0.00873
#        92/1    1.35260    1.44522 +/- 0.00870
#        93/1    1.51435    1.44605 +/- 0.00864
#        94/1    1.35010    1.44491 +/- 0.00861
#        95/1    1.49753    1.44553 +/- 0.00853
#        96/1    1.42614    1.44530 +/- 0.00843
#        97/1    1.41064    1.44490 +/- 0.00834
#        98/1    1.48753    1.44539 +/- 0.00826
#        99/1    1.43520    1.44527 +/- 0.00817
#       100/1    1.49079    1.44578 +/- 0.00810
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.0101e-01 seconds
#    Reading cross sections          = 3.7250e-01 seconds
#  Total time in simulation          = 5.6787e-01 seconds
#    Time in transport only          = 5.5311e-01 seconds
#    Time in inactive batches        = 1.1675e-01 seconds
#    Time in active batches          = 4.5112e-01 seconds
#    Time synchronizing fission bank = 2.5977e-03 seconds
#      Sampling source sites         = 1.5911e-03 seconds
#      SEND/RECV source sites        = 6.1006e-04 seconds
#    Time accumulating tallies       = 3.5855e-05 seconds
#    Time writing statepoints        = 2.1474e-03 seconds
#  Total time for finalization       = 4.0000e-07 seconds
#  Total time elapsed                = 9.7952e-01 seconds
#  Calculation Rate (inactive)       = 42825.5 particles/second
#  Calculation Rate (active)         = 99752.1 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.45208 +/- 0.00622
#  k-effective (Track-length)  = 1.44578 +/- 0.00810
#  k-effective (Absorption)    = 1.45228 +/- 0.00425
#  Combined k-effective        = 1.45178 +/- 0.00400
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:15:21
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.47290
#         2/1    1.40535
#         3/1    1.62286
#         4/1    1.53740
#         5/1    1.53136
#         6/1    1.39379
#         7/1    1.41225
#         8/1    1.48751
#         9/1    1.61164
#        10/1    1.41855
#        11/1    1.45721
#        12/1    1.39068    1.42395 +/- 0.03327
#        13/1    1.48086    1.44292 +/- 0.02699
#        14/1    1.49009    1.45471 +/- 0.02244
#        15/1    1.42391    1.44855 +/- 0.01844
#        16/1    1.48139    1.45402 +/- 0.01602
#        17/1    1.38797    1.44459 +/- 0.01650
#        18/1    1.38210    1.43678 +/- 0.01629
#        19/1    1.40029    1.43272 +/- 0.01492
#        20/1    1.39801    1.42925 +/- 0.01379
#        21/1    1.51111    1.43669 +/- 0.01453
#        84/1    1.53325    1.46290 +/- 0.00846
#        85/1    1.45153    1.46275 +/- 0.00834
#        86/1    1.45588    1.46266 +/- 0.00823
#        87/1    1.55050    1.46380 +/- 0.00821
#        88/1    1.35043    1.46235 +/- 0.00823
#        89/1    1.46558    1.46239 +/- 0.00813
#        90/1    1.38451    1.46142 +/- 0.00808
#        91/1    1.33951    1.45991 +/- 0.00812
#        92/1    1.35426    1.45862 +/- 0.00813
#        93/1    1.44478    1.45846 +/- 0.00803
#        94/1    1.44660    1.45831 +/- 0.00793
#        95/1    1.54002    1.45928 +/- 0.00790
#        96/1    1.53051    1.46010 +/- 0.00785
#        97/1    1.36777    1.45904 +/- 0.00783
#        98/1    1.48762    1.45937 +/- 0.00775
#        99/1    1.52911    1.46015 +/- 0.00770
#       100/1    1.38534    1.45932 +/- 0.00766
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.6358e-01 seconds
#    Reading cross sections          = 3.4848e-01 seconds
#  Total time in simulation          = 7.9678e-01 seconds
#    Time in transport only          = 7.8310e-01 seconds
#    Time in inactive batches        = 1.9162e-01 seconds
#    Time in active batches          = 6.0515e-01 seconds
#    Time synchronizing fission bank = 2.1302e-03 seconds
#      Sampling source sites         = 1.4010e-03 seconds
#      SEND/RECV source sites        = 3.2009e-04 seconds
#    Time accumulating tallies       = 3.5438e-05 seconds
#    Time writing statepoints        = 2.2921e-03 seconds
#  Total time for finalization       = 5.4100e-07 seconds
#  Total time elapsed                = 1.1711e+00 seconds
#  Calculation Rate (inactive)       = 26093 particles/second
#  Calculation Rate (active)         = 74361.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.44623 +/- 0.00514
#  k-effective (Track-length)  = 1.45932 +/- 0.00766
#  k-effective (Absorption)    = 1.44835 +/- 0.00448
#  Combined k-effective        = 1.44815 +/- 0.00412
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# Alright, now we have the k-eigenvalue for several pitch and void values, and we have the void coefficient at several pitch values. It is time to visualize them somehow. Try to create a figure which shows the void coefficient vs the moderator to fuel ratio and an other figure which shows the k-eigenvalue vs the moderator to fuel ratio for each void levels.
#
# Conclude your findings: how would you design a reactor core? which moderator to fuel ratio would you select?

# %%
# mfr=#your code comes here

# plt.figure()
# #your code comes here to visualize the void coefficient vs moderator to fuel ratio
# plt.show()

# plt.figure()
# #your code comes here to visualize the k-eigenvalue vs moderator to fuel ratio
# plt.show()

mfr_vals=[]


fuel_outerr=0.41
clad_outerr=0.45

for pi in pitch:
    mfr=(pi**2-clad_outerr**2*np.pi)/(fuel_outerr**2*np.pi) #your code comes here
    mfr_vals.append(mfr)

void_coeff_list = [void_coeffs[pi] for pi in pitch]

plt.figure()
plt.plot(mfr_vals, void_coeff_list, linewidth=2.0,marker='o')
plt.title('Void coefficient vs moderator to fuel ratio')
plt.xlabel('Moderator-to-Fuel Ratio')
plt.ylabel('d(Δk/k)/d(%void)')
plt.grid()
plt.show()


plt.figure()
for i, v in enumerate(void):
    k_list = [k_effs[pi][i] for pi in pitch]
    plt.plot(mfr_vals, k_list,marker='o', label=f'Void {v}%')

plt.xlabel('Moderator-to-Fuel Ratio')
plt.ylabel('k-infinity')
plt.title('k-infinity vs. Moderator-to-Fuel Ratio')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Change this line to your conclusion!

# %% [markdown]
# ## Experiment 3
#
# Wow, we saw some interesting curve there, the k-infinity first increased with increasing the pitch and then it started to to decrease. Intuitively one expects that there are two competing physical phenonema at play here. And our intuition is correct. If you remember the 4-factor formula, there were two quantities which are of interest for us now to figure out why does the k-infinity change like this with the increasing pitch. And these two quantities are:
#
# **Resonance escape probability**: probability for fast neutrons to slow-down to thermal energies without being absorbed in the resonance region of absorbers
#
# $$p=1-\frac{\int_{V_{f}} \int_{\sim 5kT}^\infty \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{f}} \int_0^{\infty} \nu(E)\Sigma_f(r,E)\phi(r,E)dVdE}$$
#
#
# **Thermal utilization factor**: the ratio of the number of thermal neutrons absorbed in the fuel and the number of thermal neutrons absorbed in all materials
#
# $$f=\frac{\int_{V_{f}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}{\int_{V_{t}} \int_0^{\sim 5kT} \Sigma_a(r,E)\phi(r,E)dVdE}$$
#
# The nominators and the denominators look like the expressions we used to define the tallies. The "scores" here are absorption, and nu-fission and the filters are the energy bounds and the spatial regions. So let's add these tallies to our `pincell()` function (for the tallies we will need to fix the ID, since we will refer to them later):

# %%
# def pincell(pitch):
#     #your input comes here, you can remove the void from your previous function
#     #tallies
#     T=1200
#     k=8.617333262145e-5
#     energy_filter = openmc.EnergyFilter([0., 5*k*T, 20.0e6])
#     fuel_filter = openmc.CellFilter(fuel)
#     moderator_filter = openmc.CellFilter(moderator)
#     tally1 = openmc.Tally(1)
#     tally1.filters = [fuel_filter,energy_filter]
#     tally1.scores = ['absorption','nu-fission']
    
#     tally2 = openmc.Tally(2)
#     tally2.filters = [moderator_filter,energy_filter]
#     tally2.scores = ['absorption']
#     tallies = openmc.Tallies([tally1, tally2])
#     model = openmc.model.Model(geom, mats, settings,tallies)
#     return model

def pincell_exp3(pitch):
    uo2 = openmc.Material(name="uo2",temperature=1200)
    # Adding nuclides to uo2
    uo2.add_nuclide('U235', 0.04)
    uo2.add_nuclide('U238', 0.96)
    uo2.add_nuclide('O16', 2.0)
    uo2.set_density('g/cm3', 10.5)


    #cladding
    zirconium = openmc.Material(name="zirconium",temperature=900)
    zirconium.add_element('Zr', 1.0)
    zirconium.set_density('g/cm3', 6.6)

    #coolant
    water = openmc.Material(name="h2o")
    water.add_nuclide('H1', 2.0)
    water.add_nuclide('O16', 1.0)
    roh_0 = 0.74
    water.set_density('g/cm3', roh_0)
    water.add_s_alpha_beta('c_H_in_H2O') #thermal scattering law to better model how low-energy neutrons interact with hydrogen bound in water molecules.
    print(water.temperature)    
    mats = openmc.Materials([uo2, zirconium, water])


    fuel_or = openmc.ZCylinder(r=0.41) #fuel cylinder with outer radius
    clad_ir = openmc.ZCylinder(r=0.42) #clad inner cylinder with inner radius
    clad_or = openmc.ZCylinder(r=0.45) #clad outer cylinder with outer radius

    fuel_region = -fuel_or                #inside the fuel cylinder
    gap_region = +fuel_or & -clad_ir      #outside of fuel cylinder and inside of clad inner cylinder
    clad_region = +clad_ir & -clad_or     #outside of clad inner cylinder and inside of clad outer cylinder

    fuel = openmc.Cell(name='fuel')
    fuel.fill = uo2
    fuel.region = fuel_region

    gap = openmc.Cell(name='air gap')
    gap.region = gap_region

    clad = openmc.Cell(name='clad')
    clad.fill = zirconium
    clad.region = clad_region


    #we define the x and y planes with boundary condition
    left = openmc.XPlane(x0=-pitch/2, boundary_type='reflective')
    right = openmc.XPlane(x0=pitch/2, boundary_type='reflective')
    bottom = openmc.YPlane(y0=-pitch/2, boundary_type='reflective')
    top = openmc.YPlane(y0=pitch/2, boundary_type='reflective')

    #outside of left and inside of right, outside of bottom, and inside of top and outside of clad outer cylinder
    water_region = +left & -right & +bottom & -top & +clad_or

    moderator = openmc.Cell(name='moderator')
    moderator.fill = water
    moderator.region = water_region

    root = openmc.Universe(cells=(fuel, gap, clad, moderator))

    geom = openmc.Geometry()
    geom.root_universe = root

    point = openmc.stats.Point((0, 0, 0))
    src = openmc.IndependentSource(space=point)

    settings = openmc.Settings()
    settings.source = src
    settings.batches = 100
    settings.inactive = 10
    settings.particles = 500
    settings.output = {'tallies': False}

    #tallies
    T=1200
    k=8.617333262145e-5
    energy_filter = openmc.EnergyFilter([0., 5*k*T, 20.0e6])
    fuel_filter = openmc.CellFilter(fuel)
    moderator_filter = openmc.CellFilter(moderator)
    tally1 = openmc.Tally(name='fuel_rates')
    tally1.filters = [fuel_filter,energy_filter]
    tally1.scores = ['absorption','nu-fission']

    tally2 = openmc.Tally(name='moderator_abs')
    tally2.filters = [moderator_filter,energy_filter]
    tally2.scores = ['absorption']
    tallies = openmc.Tallies([tally1, tally2])
    model = openmc.model.Model(geom, mats, settings,tallies)
    return model

# %% [markdown]
# Now we just have to figure out how to compute $p$ and $f$ from the tallies. First it is best to remind ourselves how to load in the tally results, and you can do some trial and error to figure out these values. Let's run a computation with our model.

# %%
# os.system('rm *h5')
# mod=pincell(1.26)
# output = mod.run()


import os
import glob

demo_dir = 'openmc_exp3_demo'
os.makedirs(demo_dir, exist_ok=True)

# Clean only expected OpenMC outputs inside the demo directory.
for f in glob.glob(os.path.join(demo_dir, 'statepoint.*.h5')) + [os.path.join(demo_dir, 'summary.h5')]:
    if os.path.exists(f):
        os.remove(f)

mod = pincell_exp3(1.26)
output = mod.run(cwd=demo_dir)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:22:44
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature:
#        64/1    1.35331    1.38188 +/- 0.01018
#        65/1    1.31965    1.38075 +/- 0.01005
#        66/1    1.30867    1.37946 +/- 0.00996
#        67/1    1.46960    1.38104 +/- 0.00991
#        68/1    1.47151    1.38260 +/- 0.00986
#        69/1    1.40501    1.38298 +/- 0.00970
#        70/1    1.29733    1.38156 +/- 0.00964
#        71/1    1.40746    1.38198 +/- 0.00949
#        72/1    1.39428    1.38218 +/- 0.00934
#        73/1    1.46738    1.38353 +/- 0.00929
#        74/1    1.36662    1.38327 +/- 0.00915
#        75/1    1.30974    1.38214 +/- 0.00907
#        76/1    1.27443    1.38050 +/- 0.00908
#        77/1    1.51128    1.38246 +/- 0.00916
#        78/1    1.35435    1.38204 +/- 0.00903
#        79/1    1.49015    1.38361 +/- 0.00904
#        80/1    1.36247    1.38331 +/- 0.00891
#        81/1    1.30488    1.38220 +/- 0.00885
#        82/1    1.38992    1.38231 +/- 0.00873
#        83/1    1.39697    1.38251 +/- 0.00861
#        84/1    1.33851    1.38192 +/- 0.00852
#        85/1    1.39583    1.38210 +/- 0.00840
#        86/1    1.57426    1.38463 +/- 0.00867
#        87/1    1.49522    1.38607 +/- 0.00868
#        88/1    1.45589    1.38696 +/- 0.00861
#        89/1    1.45131    1.38778 +/- 0.00854
#        90/1    1.46044    1.38868 +/- 0.00848
#        91/1    1.30945    1.38771 +/- 0.00843
#        92/1    1.28086    1.38640 +/- 0.00843
#        93/1    1.37388    1.38625 +/- 0.00833
#        94/1    1.39566    1.38636 +/- 0.00823
#        95/1    1.49511    1.38764 +/- 0.00823
#        96/1    1.46393    1.38853 +/- 0.00819
#        97/1    1.39902    1.38865 +/- 0.00809
#        98/1    1.39078    1.38868 +/- 0.00800
#        99/1    1.43912    1.38924 +/- 0.00793
#       100/1    1.45095    1.38993 +/- 0.00787
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 5.3264e-01 seconds
#    Reading cross sections          = 5.1601e-01 seconds
#  Total time in simulation          = 9.5528e-01 seconds
#    Time in transport only          = 6.6577e-01 seconds
#    Time in inactive batches        = 8.8665e-02 seconds
#    Time in active batches          = 8.6662e-01 seconds
#    Time synchronizing fission bank = 2.7109e-03 seconds
#      Sampling source sites         = 1.8817e-03 seconds
#      SEND/RECV source sites        = 3.9580e-04 seconds
#    Time accumulating tallies       = 2.6170e-01 seconds
#    Time writing statepoints        = 7.2748e-03 seconds
#  Total time for finalization       = 6.9940e-06 seconds
#  Total time elapsed                = 1.4987e+00 seconds
#  Calculation Rate (inactive)       = 56391.8 particles/second
#  Calculation Rate (active)         = 51926 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.38725 +/- 0.00662
#  k-effective (Track-length)  = 1.38993 +/- 0.00787
#  k-effective (Absorption)    = 1.38700 +/- 0.00441
#  Combined k-effective        = 1.38731 +/- 0.00427
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# And now load in the tallies. And from there you can perform the necessary operations to obtain $p$ and $f$.

# %%
sp = openmc.StatePoint(output)
tallydf1 = sp.tallies[1].get_pandas_dataframe()
tallydf1
# Out:
#    cell  energy low [eV]  energy high [eV] nuclide       score     mean  \
# 0   217         0.00e+00          5.17e-01   total  absorption 5.68e-01
# 1   217         0.00e+00          5.17e-01   total  nu-fission 1.07e+00
# 2   217         5.17e-01          2.00e+07   total  absorption 3.91e-01
# 3   217         5.17e-01          2.00e+07   total  nu-fission 3.24e-01
#
#    std. dev.
# 0   4.12e-03
# 1   7.75e-03
# 2   2.10e-03
# 3   1.39e-03

# %%
sp = openmc.StatePoint(output)
tallydf2 = sp.tallies[2].get_pandas_dataframe()
tallydf2
# Out:
#    cell  energy low [eV]  energy high [eV] nuclide       score     mean  \
# 0   220         0.00e+00          5.17e-01   total  absorption 3.17e-02
# 1   220         5.17e-01          2.00e+07   total  absorption 6.25e-03
#
#    std. dev.
# 0   2.35e-04
# 1   4.30e-05

# %%
#test here how p and f should be estimated

with openmc.StatePoint(output) as sp:
    t1 = sp.get_tally(name='fuel_rates').get_pandas_dataframe()
    t2 = sp.get_tally(name='moderator_abs').get_pandas_dataframe()

# Tally #1 (fuel)
fuel_abs_thermal = t1.loc[(t1['score']=='absorption') & (t1['energy low [eV]']==0.0), 'mean'].values[0]
fuel_abs_fast = t1.loc[(t1['score']=='absorption') & (t1['energy low [eV]']>0.0), 'mean'].values[0]
fuel_nufission_thermal = t1.loc[(t1['score']=='nu-fission') & (t1['energy low [eV]']==0.0), 'mean'].values[0]
fuel_nufission_fast = t1.loc[(t1['score']=='nu-fission') & (t1['energy low [eV]']>0.0), 'mean'].values[0]
fuel_nufission_tot = fuel_nufission_thermal + fuel_nufission_fast

# Tally #2 (moderator)
mod_abs_thermal = t2.loc[(t2['score']=='absorption') & (t2['energy low [eV]']==0.0), 'mean'].values[0]

# p and f
p_value = 1.0 - (fuel_abs_fast / fuel_nufission_tot)
f_value = fuel_abs_thermal / (fuel_abs_thermal + mod_abs_thermal)

print("p =", p_value, "f =", f_value)
# Out:
# p = 0.7183320323585115 f = 0.9471278697116035

# %% [markdown]
# Once we know how to get these quantities we can loop through several pitch values to see how they change with the moderator to fuel ratio!

# %%
# pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]
# os.system('rm *h5')
# keff=[]
# p=[]
# f=[]
# for pi in pitch:
#     #create a model
#     #run the model
#     #read the statepoint file and the tallies
#     keff.append#complete the line
#     p.append#complete the line
#     f.append#complete the line
#     os.system('rm *h5')

import tempfile

pitch=[0.95,1.05,1.15,1.25,1.35,1.45,1.55,1.65,1.75,1.85,1.95,2.05,2.15,2.25,2.35,2.45,2.55,2.65,2.75,2.85,2.95]

#initialize lists to store results
k_effs=[] #store k_eff values pr pitch
p=[]
f=[]

for pi in pitch:
    try:
        mod = pincell_exp3(pi)
        with tempfile.TemporaryDirectory(prefix='openmc_exp3_') as run_dir:
            output = mod.run(cwd=run_dir)
            with openmc.StatePoint(output) as sp:
                k_effs.append(sp.keff.nominal_value)

                t1 = sp.get_tally(name='fuel_rates').get_pandas_dataframe()
                t2 = sp.get_tally(name='moderator_abs').get_pandas_dataframe()

        # Tally #1 (fuel)
        fuel_abs_thermal = t1.loc[(t1['score']=='absorption') & (t1['energy low [eV]']==0.0), 'mean'].values[0]
        fuel_abs_fast = t1.loc[(t1['score']=='absorption') & (t1['energy low [eV]']>0.0), 'mean'].values[0]
        fuel_nufission_thermal = t1.loc[(t1['score']=='nu-fission') & (t1['energy low [eV]']==0.0), 'mean'].values[0]
        fuel_nufission_fast = t1.loc[(t1['score']=='nu-fission') & (t1['energy low [eV]']>0.0), 'mean'].values[0]
        fuel_nufission_tot = fuel_nufission_thermal + fuel_nufission_fast

        # Tally #2 (moderator)
        mod_abs_thermal = t2.loc[(t2['score']=='absorption') & (t2['energy low [eV]']==0.0), 'mean'].values[0]

        # p and f
        p_value = 1.0 - (fuel_abs_fast / fuel_nufission_tot)
        f_value = fuel_abs_thermal / (fuel_abs_thermal + mod_abs_thermal)

        p.append(p_value)
        f.append(f_value)
    except RuntimeError as err:
        print(f'OpenMC run failed at pitch={pi}: {err}')
        k_effs.append(np.nan)
        p.append(np.nan)
        f.append(np.nan)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:23:53
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.13108
#         2/1    1.19509
#         3/1    1.06296
#         4/1    1.08344
#         5/1    1.12917
#         6/1    1.11927
#         7/1    1.24359
#         8/1    1.10066
#         9/1    1.28129
#        10/1    0.98728
#        11/1    1.18755
#        12/1    1.13699    1.16227 +/- 0.02528
#        13/1    1.11054    1.14503 +/- 0.02259
#        14/1    1.03393    1.11725 +/- 0.03204
#        15/1    1.32699    1.15920 +/- 0.04874
#        16/1    1.14684    1.15714 +/- 0.03985
#        17/1    1.04378    1.14095 +/- 0.03737
#        18/1    1.07724    1.13298 +/- 0.03333
#        19/1    1.14427    1.13424 +/- 0.02942
#        20/1    1.16119    1.13693 +/- 0.02645
#        21/1    1.13675    1.13692 +/- 0.02393
#        22/1    1.02633    1.12770 +/- 0.02371
#        23/1    0.94762    1.11385 +/- 0.02583
#        24/1    1.10315    1.11308 +/- 0.02393
#        25/1    1.13876    1.11480 +/- 0.02234
#        26/1    1.02921    1.10945 +/- 0.02157
#        27/1    1.13992    1.11124 +/- 0.02034
#        28/1    1.15243    1.11353 +/- 0.01932
#        91/1    1.06919    1.09110 +/- 0.00831
#        92/1    1.05846    1.09070 +/- 0.00822
#        93/1    1.07481    1.09051 +/- 0.00812
#        94/1    1.09029    1.09050 +/- 0.00803
#        95/1    1.11024    1.09074 +/- 0.00794
#        96/1    1.17334    1.09170 +/- 0.00790
#        97/1    1.12247    1.09205 +/- 0.00782
#        98/1    1.11445    1.09230 +/- 0.00773
#        99/1    1.25562    1.09414 +/- 0.00786
#       100/1    1.05664    1.09372 +/- 0.00779
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 6.0479e-01 seconds
#    Reading cross sections          = 5.8784e-01 seconds
#  Total time in simulation          = 1.0907e+00 seconds
#    Time in transport only          = 8.8558e-01 seconds
#    Time in inactive batches        = 8.1231e-02 seconds
#    Time in active batches          = 1.0094e+00 seconds
#    Time synchronizing fission bank = 2.6474e-03 seconds
#      Sampling source sites         = 1.8424e-03 seconds
#      SEND/RECV source sites        = 4.3034e-04 seconds
#    Time accumulating tallies       = 1.8241e-01 seconds
#    Time writing statepoints        = 3.3161e-03 seconds
#  Total time for finalization       = 5.4000e-06 seconds
#  Total time elapsed                = 1.7049e+00 seconds
#  Calculation Rate (inactive)       = 61553 particles/second
#  Calculation Rate (active)         = 44578.9 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.09352 +/- 0.00613
#  k-effective (Track-length)  = 1.09372 +/- 0.00779
#  k-effective (Absorption)    = 1.08592 +/- 0.00502
#  Combined k-effective        = 1.08872 +/- 0.00448
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:23:55
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.19083
#         2/1    1.15291
#         3/1    1.32912
#         4/1    1.31115
#         5/1    1.14856
#         6/1    1.16483
#         7/1    1.16505
#         8/1    1.30030
#         9/1    1.23075
#        10/1    1.22838
#        11/1    1.28657
#        12/1    1.14742    1.21699 +/- 0.06958
#        13/1    1.24648    1.22682 +/- 0.04136
#        14/1    1.14893    1.20735 +/- 0.03513
#        15/1    1.20045    1.20597 +/- 0.02725
#        16/1    1.15352    1.19723 +/- 0.02390
#        17/1    1.21380    1.19960 +/- 0.02034
#        18/1    1.28601    1.21040 +/- 0.02066
#        19/1    1.24607    1.21436 +/- 0.01865
#        20/1    1.26322    1.21925 +/- 0.01738
#        21/1    1.13603    1.21168 +/- 0.01745
#        84/1    1.15577    1.21753 +/- 0.00838
#        85/1    1.18541    1.21710 +/- 0.00828
#        86/1    1.27644    1.21788 +/- 0.00821
#        87/1    1.15459    1.21706 +/- 0.00814
#        88/1    1.28114    1.21788 +/- 0.00808
#        89/1    1.29928    1.21891 +/- 0.00804
#        90/1    1.12885    1.21779 +/- 0.00802
#        91/1    1.17168    1.21722 +/- 0.00794
#        92/1    1.24863    1.21760 +/- 0.00785
#        93/1    1.40247    1.21983 +/- 0.00807
#        94/1    1.21439    1.21976 +/- 0.00798
#        95/1    1.17907    1.21929 +/- 0.00790
#        96/1    1.20310    1.21910 +/- 0.00781
#        97/1    1.27199    1.21971 +/- 0.00774
#        98/1    1.16287    1.21906 +/- 0.00768
#        99/1    1.14815    1.21826 +/- 0.00763
#       100/1    1.35238    1.21975 +/- 0.00769
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.2086e-01 seconds
#    Reading cross sections          = 4.0305e-01 seconds
#  Total time in simulation          = 8.5610e-01 seconds
#    Time in transport only          = 6.7776e-01 seconds
#    Time in inactive batches        = 1.3966e-01 seconds
#    Time in active batches          = 7.1643e-01 seconds
#    Time synchronizing fission bank = 2.5810e-03 seconds
#      Sampling source sites         = 1.5830e-03 seconds
#      SEND/RECV source sites        = 5.0576e-04 seconds
#    Time accumulating tallies       = 1.5993e-01 seconds
#    Time writing statepoints        = 4.2697e-03 seconds
#  Total time for finalization       = 5.2010e-06 seconds
#  Total time elapsed                = 1.2857e+00 seconds
#  Calculation Rate (inactive)       = 35800.2 particles/second
#  Calculation Rate (active)         = 62811.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.22226 +/- 0.00579
#  k-effective (Track-length)  = 1.21975 +/- 0.00769
#  k-effective (Absorption)    = 1.22786 +/- 0.00473
#  Combined k-effective        = 1.22643 +/- 0.00447
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:23:56
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.19850
#         2/1    1.17707
#         3/1    1.36089
#         4/1    1.29770
#         5/1    1.32666
#         6/1    1.40337
#         7/1    1.43093
#         8/1    1.45625
#         9/1    1.32262
#        10/1    1.37724
#        11/1    1.14521
#        12/1    1.53193    1.33857 +/- 0.19336
#        13/1    1.26872    1.31529 +/- 0.11404
#        14/1    1.26028    1.30154 +/- 0.08180
#        15/1    1.34358    1.30995 +/- 0.06392
#        78/1    1.27052    1.31096 +/- 0.01098
#        79/1    1.31932    1.31108 +/- 0.01082
#        80/1    1.29800    1.31089 +/- 0.01067
#        81/1    1.22319    1.30966 +/- 0.01059
#        82/1    1.31174    1.30969 +/- 0.01044
#        83/1    1.15252    1.30753 +/- 0.01052
#        84/1    1.11781    1.30497 +/- 0.01069
#        85/1    1.35877    1.30569 +/- 0.01057
#        86/1    1.26628    1.30517 +/- 0.01044
#        87/1    1.33736    1.30559 +/- 0.01031
#        88/1    1.17536    1.30392 +/- 0.01032
#        89/1    1.27371    1.30353 +/- 0.01019
#        90/1    1.31988    1.30374 +/- 0.01007
#        91/1    1.25680    1.30316 +/- 0.00996
#        92/1    1.33807    1.30359 +/- 0.00985
#        93/1    1.26902    1.30317 +/- 0.00974
#        94/1    1.31127    1.30327 +/- 0.00962
#        95/1    1.26397    1.30280 +/- 0.00952
#        96/1    1.30508    1.30283 +/- 0.00941
#        97/1    1.38899    1.30382 +/- 0.00935
#        98/1    1.34272    1.30426 +/- 0.00925
#        99/1    1.43679    1.30575 +/- 0.00927
#       100/1    1.31701    1.30588 +/- 0.00917
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.6324e-01 seconds
#    Reading cross sections          = 4.4767e-01 seconds
#  Total time in simulation          = 7.5840e-01 seconds
#    Time in transport only          = 6.0769e-01 seconds
#    Time in inactive batches        = 9.4281e-02 seconds
#    Time in active batches          = 6.6412e-01 seconds
#    Time synchronizing fission bank = 3.3911e-03 seconds
#      Sampling source sites         = 1.9164e-03 seconds
#      SEND/RECV source sites        = 1.1231e-03 seconds
#    Time accumulating tallies       = 1.3188e-01 seconds
#    Time writing statepoints        = 3.0028e-03 seconds
#  Total time for finalization       = 5.0200e-06 seconds
#  Total time elapsed                = 1.2427e+00 seconds
#  Calculation Rate (inactive)       = 53032.8 particles/second
#  Calculation Rate (active)         = 67759 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.31150 +/- 0.00753
#  k-effective (Track-length)  = 1.30588 +/- 0.00917
#  k-effective (Absorption)    = 1.31773 +/- 0.00490
#  Combined k-effective        = 1.31706 +/- 0.00489
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:23:57
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1
#        71/1    1.42712    1.38398 +/- 0.01026
#        72/1    1.38120    1.38393 +/- 0.01009
#        73/1    1.34900    1.38338 +/- 0.00995
#        74/1    1.38929    1.38347 +/- 0.00979
#        75/1    1.37450    1.38333 +/- 0.00964
#        76/1    1.37094    1.38315 +/- 0.00949
#        77/1    1.40417    1.38346 +/- 0.00936
#        78/1    1.40303    1.38375 +/- 0.00922
#        79/1    1.42208    1.38430 +/- 0.00910
#        80/1    1.32287    1.38342 +/- 0.00902
#        81/1    1.39933    1.38365 +/- 0.00889
#        82/1    1.50236    1.38530 +/- 0.00892
#        83/1    1.28863    1.38397 +/- 0.00890
#        84/1    1.28581    1.38265 +/- 0.00888
#        85/1    1.35172    1.38223 +/- 0.00877
#        86/1    1.51088    1.38393 +/- 0.00881
#        87/1    1.43796    1.38463 +/- 0.00873
#        88/1    1.51505    1.38630 +/- 0.00878
#        89/1    1.54562    1.38832 +/- 0.00889
#        90/1    1.31682    1.38742 +/- 0.00883
#        91/1    1.35165    1.38698 +/- 0.00873
#        92/1    1.28754    1.38577 +/- 0.00871
#        93/1    1.40614    1.38602 +/- 0.00861
#        94/1    1.28251    1.38478 +/- 0.00859
#        95/1    1.21975    1.38284 +/- 0.00871
#        96/1    1.39469    1.38298 +/- 0.00861
#        97/1    1.30947    1.38213 +/- 0.00855
#        98/1    1.48033    1.38325 +/- 0.00853
#        99/1    1.38749    1.38330 +/- 0.00843
#       100/1    1.31577    1.38255 +/- 0.00837
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8950e-01 seconds
#    Reading cross sections          = 3.6320e-01 seconds
#  Total time in simulation          = 7.7714e-01 seconds
#    Time in transport only          = 6.2963e-01 seconds
#    Time in inactive batches        = 1.6058e-01 seconds
#    Time in active batches          = 6.1656e-01 seconds
#    Time synchronizing fission bank = 2.4847e-03 seconds
#      Sampling source sites         = 1.4401e-03 seconds
#      SEND/RECV source sites        = 5.0320e-04 seconds
#    Time accumulating tallies       = 1.3180e-01 seconds
#    Time writing statepoints        = 3.7703e-03 seconds
#  Total time for finalization       = 5.1400e-06 seconds
#  Total time elapsed                = 1.1766e+00 seconds
#  Calculation Rate (inactive)       = 31137.8 particles/second
#  Calculation Rate (active)         = 72985.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.37990 +/- 0.00617
#  k-effective (Track-length)  = 1.38255 +/- 0.00837
#  k-effective (Absorption)    = 1.38379 +/- 0.00492
#  Combined k-effective        = 1.38235 +/- 0.00445
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:23:59
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature:
#        84/1    1.30548    1.20774 +/- 0.00737
#        85/1    1.29126    1.20886 +/- 0.00736
#        86/1    1.28694    1.20988 +/- 0.00733
#        87/1    1.17374    1.20941 +/- 0.00725
#        88/1    1.24942    1.20993 +/- 0.00717
#        89/1    1.12950    1.20891 +/- 0.00716
#        90/1    1.25080    1.20943 +/- 0.00709
#        91/1    1.15083    1.20871 +/- 0.00703
#        92/1    1.09604    1.20734 +/- 0.00708
#        93/1    1.14579    1.20659 +/- 0.00704
#        94/1    1.14294    1.20584 +/- 0.00699
#        95/1    1.23119    1.20613 +/- 0.00692
#        96/1    1.30434    1.20728 +/- 0.00693
#        97/1    1.22950    1.20753 +/- 0.00686
#        98/1    1.21402    1.20761 +/- 0.00678
#        99/1    1.18891    1.20740 +/- 0.00670
#       100/1    1.15407    1.20680 +/- 0.00666
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.8365e-01 seconds
#    Reading cross sections          = 3.6659e-01 seconds
#  Total time in simulation          = 9.4006e-01 seconds
#    Time in transport only          = 7.5757e-01 seconds
#    Time in inactive batches        = 2.0069e-01 seconds
#    Time in active batches          = 7.3937e-01 seconds
#    Time synchronizing fission bank = 2.4223e-03 seconds
#      Sampling source sites         = 1.7092e-03 seconds
#      SEND/RECV source sites        = 3.3224e-04 seconds
#    Time accumulating tallies       = 1.6559e-01 seconds
#    Time writing statepoints        = 3.6293e-03 seconds
#  Total time for finalization       = 7.1440e-06 seconds
#  Total time elapsed                = 1.3477e+00 seconds
#  Calculation Rate (inactive)       = 24914 particles/second
#  Calculation Rate (active)         = 60862.5 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.21034 +/- 0.00525
#  k-effective (Track-length)  = 1.20680 +/- 0.00666
#  k-effective (Absorption)    = 1.20532 +/- 0.00435
#  Combined k-effective        = 1.20618 +/- 0.00403
#  Leakage Fraction            = 0.00000 +/- 0.00000
#
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2025 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.15.3
#      Commit Hash | 27e38e894697bb32a1dac7848d2618818b6b8daf
#        Date/Time | 2026-04-28 11:24:20
#    MPI Processes | 1
#   OpenMP Threads | 32
#
#  Reading model XML file 'model.xml' ...
#  Reading cross sections XML file...
#  Reading U235 from /root/jeff-3.3-hdf5/U235.h5
#  Reading U238 from /root/jeff-3.3-hdf5/U238.h5
#  Reading O16 from /root/jeff-3.3-hdf5/O16.h5
#  Reading Zr90 from /root/jeff-3.3-hdf5/Zr90.h5
#  Reading Zr91 from /root/jeff-3.3-hdf5/Zr91.h5
#  Reading Zr92 from /root/jeff-3.3-hdf5/Zr92.h5
#  Reading Zr94 from /root/jeff-3.3-hdf5/Zr94.h5
#  Reading Zr96 from /root/jeff-3.3-hdf5/Zr96.h5
#  Reading H1 from /root/jeff-3.3-hdf5/H1.h5
#  Reading c_H_in_H2O from /root/jeff-3.3-hdf5/c_H_in_H2O.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 1200 K
#  Preparing distributed cell instances...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 20000000 eV for H1
#  Initializing source particles...
#
#  ====================>     K EIGENVALUE SIMULATION     <====================
#
#   Bat./Gen.      k            Average k
#   =========   ========   ====================
#         1/1    1.24716
#         2/1    1.14904
#         3/1    1.10358
#         4/1    1.18625
#         5/1    1.10764
#         6/1    1.17230
#         7/1    1.23542
#         8/1    1.22582
#         9/1    1.37619
#        10/1    1.20039
#        11/1    1.08345
#        12/1    1.18549    1.13447 +/- 0.05102
#        13/1    1.08583    1.11826 +/- 0.03362
#        14/1    1.17789    1.13317 +/- 0.02806
#        77/1    1.14124    1.18158 +/- 0.00726
#        78/1    1.18647    1.18166 +/- 0.00716
#        79/1    1.24123    1.18252 +/- 0.00711
#        80/1    1.15952    1.18219 +/- 0.00701
#        81/1    1.17345    1.18207 +/- 0.00691
#        82/1    1.18984    1.18218 +/- 0.00682
#        83/1    1.09686    1.18101 +/- 0.00682
#        84/1    1.21236    1.18143 +/- 0.00674
#        85/1    1.21984    1.18194 +/- 0.00667
#        86/1    1.13454    1.18132 +/- 0.00661
#        87/1    1.19045    1.18144 +/- 0.00653
#        88/1    1.14531    1.18097 +/- 0.00646
#        89/1    1.08084    1.17971 +/- 0.00650
#        90/1    1.18635    1.17979 +/- 0.00642
#        91/1    1.09383    1.17873 +/- 0.00643
#        92/1    1.33200    1.18060 +/- 0.00662
#        93/1    1.15790    1.18032 +/- 0.00655
#        94/1    1.14343    1.17989 +/- 0.00648
#        95/1    1.22583    1.18043 +/- 0.00643
#        96/1    1.21679    1.18085 +/- 0.00637
#        97/1    1.19639    1.18103 +/- 0.00630
#        98/1    1.23878    1.18168 +/- 0.00626
#        99/1    1.28366    1.18283 +/- 0.00629
#       100/1    1.22534    1.18330 +/- 0.00624
#  Creating state point statepoint.100.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 4.6299e-01 seconds
#    Reading cross sections          = 4.4475e-01 seconds
#  Total time in simulation          = 8.4980e-01 seconds
#    Time in transport only          = 6.4296e-01 seconds
#    Time in inactive batches        = 1.7566e-01 seconds
#    Time in active batches          = 6.7414e-01 seconds
#    Time synchronizing fission bank = 2.4450e-03 seconds
#      Sampling source sites         = 1.4414e-03 seconds
#      SEND/RECV source sites        = 4.8438e-04 seconds
#    Time accumulating tallies       = 1.8586e-01 seconds
#    Time writing statepoints        = 3.2849e-03 seconds
#  Total time for finalization       = 4.7500e-06 seconds
#  Total time elapsed                = 1.3295e+00 seconds
#  Calculation Rate (inactive)       = 28464.4 particles/second
#  Calculation Rate (active)         = 66751.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  k-effective (Collision)     = 1.18298 +/- 0.00517
#  k-effective (Track-length)  = 1.18330 +/- 0.00624
#  k-effective (Absorption)    = 1.17787 +/- 0.00425
#  Combined k-effective        = 1.17961 +/- 0.00389
#  Leakage Fraction            = 0.00000 +/- 0.00000

# %% [markdown]
# Finally we are ready to visualize our results and then conclude our findings. Try to summarize with few words the underlying physics what we just discovered here.

# %%
# mfr=#complete the line

# plt.figure()
# plt.plot(mfr,keff,label='k-inf')
# plt.plot(mfr,p,label='p')
# plt.plot(mfr,f,label='f')
# plt.legend()
# plt.xlabel('Moderator to fuel ratio')
# plt.show()

mfr_vals=[]


fuel_outerr=0.41
clad_outerr=0.45

for pi in pitch:
    mfr=(pi**2-clad_outerr**2*np.pi)/(fuel_outerr**2*np.pi) #your code comes here
    mfr_vals.append(mfr)
#print(mfr_vals)

plt.figure()
plt.plot(mfr_vals,k_effs,label='k-inf')
plt.plot(mfr_vals,p,label='p')
plt.plot(mfr_vals,f,label='f')
plt.legend()
plt.xlabel('Moderator to fuel ratio')
plt.ylabel('k-inf, p, f (dimensionless)')
plt.show()

# %% [markdown]
# Change this line to your conclusions!
#
# ![image.png](attachment:image.png)
